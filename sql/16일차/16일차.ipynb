-- %% [markdown]
-- # 16일차 SQL 데이터 분석 학습
--
-- ## 문제 1: 자동차 대여 기록에서 대여중 / 대여 가능 여부 구분하기 (Level 3)
--
-- - **문제 출처**: [프로그래머스 자동차 대여 기록에서 대여중 / 대여 가능 여부 구분하기](https://school.programmers.co.kr/learn/courses/30/lessons/157340)
--
-- ---
--
-- ### 문제 설명
--
-- CAR_RENTAL_COMPANY_RENTAL_HISTORY 테이블은 어느 자동차 대여 회사의 자동차 대여 기록 정보를 담은 테이블입니다.
-- HISTORY_ID, CAR_ID, START_DATE, END_DATE는 각각 자동차 대여 기록 ID, 자동차 ID, 대여 시작일, 대여 종료일을 의미합니다.
--
-- CAR_RENTAL_COMPANY_RENTAL_HISTORY 테이블에서 2022년 10월 16일에 대여 중인 자동차인 경우 '대여중' 이라고 표시하고, 대여 중이지 않은 자동차인 경우 '대여 가능'을 표시하는 컬럼(컬럼명: AVAILABILITY)을 추가하여 자동차 ID와 AVAILABILITY 리스트를 출력하는 SQL문을 작성해주세요.
-- 이때 반납 날짜가 2022년 10월 16일인 경우에도 '대여중'으로 표시해주시고 결과는 자동차 ID를 기준으로 내림차순 정렬해주세요.
--
-- ---
--
-- ### 예시 테이블 및 기대 결과
--
-- #### CAR_RENTAL_COMPANY_RENTAL_HISTORY (대여 기록)
-- | HISTORY_ID | CAR_ID | START_DATE | END_DATE |
-- | --- | --- | --- | --- |
-- | 1 | 4 | 2022-09-27 | 2022-11-27 |
-- | 2 | 3 | 2022-10-03 | 2022-11-04 |
-- | 3 | 2 | 2022-10-05 | 2022-10-16 |
-- | 4 | 1 | 2022-10-11 | 2022-10-14 |
-- | 5 | 3 | 2022-10-16 | 2022-10-17 |
--
-- #### 기대하는 출력 결과 (RESULT)
-- | CAR_ID | AVAILABILITY |
-- | --- | --- |
-- | 4 | 대여중 |
-- | 3 | 대여중 |
-- | 2 | 대여중 |
-- | 1 | 대여 가능 |

-- %%
-- [문제 설명]
-- CAR_RENTAL_COMPANY_RENTAL_HISTORY 테이블에서 2022년 10월 16일에 대여 중인 자동차는 '대여중', 아니면 '대여 가능'으로 표시합니다.
-- 반납 날짜(END_DATE)가 2022년 10월 16일인 경우에도 '대여중'으로 표시해야 합니다.
-- 출력 컬럼: CAR_ID, AVAILABILITY
-- 결과는 자동차 ID(CAR_ID) 기준 내림차순 정렬합니다.
SELECT

-- %% [markdown]
-- ---
--
-- ## 문제 2: 특정 세대의 대장균 찾기 (Level 4)
--
-- - **문제 출처**: [프로그래머스 특정 세대의 대장균 찾기](https://school.programmers.co.kr/learn/courses/30/lessons/301650)
--
-- ---
--
-- ### 문제 설명
--
-- ECOLI_DATA 테이블은 실험실에서 배양한 대장균 개체들의 정보를 담은 테이블입니다.
-- ID, PARENT_ID, SIZE_OF_COLONY, DIFFERENTIATION_DATE, GENOTYPE는 각각 개체 ID, 부모 개체 ID, 개체군의 크기, 분화된 날짜, 개체의 형질을 나타내는 값을 의미합니다.
--
-- 최초의 대장균(루트 대장균)은 PARENT_ID 값이 NULL 입니다.
-- 루트 대장균의 세대(GENERATION)를 1로 하며, 자식 개체의 세대는 부모 개체의 세대보다 1 큽니다.
--
-- 3세대의 대장균의 ID(ID)를 출력하는 SQL문을 작성해주세요. 이때 결과는 대장균의 ID 에 대해 오름차순 정렬해주세요.
--
-- ---
--
-- ### 예시 테이블 및 기대 결과
--
-- #### ECOLI_DATA (대장균 개체 정보)
-- | ID | PARENT_ID | SIZE_OF_COLONY | DIFFERENTIATION_DATE | GENOTYPE |
-- | --- | --- | --- | --- | --- |
-- | 1 | NULL | 10 | 2019-01-01 | 5 |
-- | 2 | NULL | 2 | 2019-01-01 | 3 |
-- | 3 | 1 | 100 | 2020-01-01 | 4 |
-- | 4 | 2 | 16 | 2020-01-01 | 4 |
-- | 5 | 2 | 17 | 2020-01-01 | 6 |
-- | 6 | 4 | 101 | 2021-01-01 | 22 |
-- | 7 | 4 | 101 | 2022-01-01 | 23 |
-- | 8 | 6 | 1 | 2022-01-01 | 27 |
--
-- #### 기대하는 출력 결과 (RESULT)
-- | ID |
-- | --- |
-- | 6 |
-- | 7 |

-- %%
-- [문제 설명]
-- ECOLI_DATA 테이블에서 3세대에 해당하는 대장균 개체의 ID를 조회합니다.
-- 루트 개체(PARENT_ID IS NULL)는 1세대, 그 자식은 2세대, 2세대의 자식은 3세대입니다.
-- 출력 컬럼: ID
-- 결과는 ID 기준 오름차순 정렬합니다.
SELECT

-- %% [markdown]
-- ---
--
-- ## 문제 3: 보호소에서 중성화한 동물 (Level 4)
--
-- - **문제 출처**: [프로그래머스 보호소에서 중성화한 동물](https://school.programmers.co.kr/learn/courses/30/lessons/59045)
--
-- ---
--
-- ### 문제 설명
--
-- 동물 보호소에 들어온 동물의 정보를 담은 ANIMAL_INS 테이블과, 동물 보호소에서 입양 보낸 동물의 정보를 담은 ANIMAL_OUTS 테이블이 있습니다.
-- ANIMAL_OUTS의 ANIMAL_ID는 ANIMAL_INS의 ANIMAL_ID의 외래 키입니다.
--
-- 보호소에서 중성화 수술을 거친 동물 정보를 알아보려 합니다.
-- 보호소에 들어올 당시에는 중성화되지 않았지만, 보호소를 나갈 당시에는 중성화된 동물의 아이디와 생물 종, 이름을 조회하는 아이디 순으로 조회하는 SQL 문을 작성해주세요.
-- 중성화를 거치지 않은 동물은 성별 및 중성화 여부에 Intact, 중성화를 거친 동물은 Spayed 또는 Neutered라고 표기되어 있습니다.
--
-- ---
--
-- ### 예시 테이블 및 기대 결과
--
-- #### ANIMAL_INS (보호소 입소 정보)
-- | ANIMAL_ID | ANIMAL_TYPE | DATETIME | INTAKE_CONDITION | NAME | SEX_UPON_INTAKE |
-- | --- | --- | --- | --- | --- | --- |
-- | A355753 | Dog | 2017-08-07 15:05:00 | Normal | Elijah | Neutered Male |
-- | A373280 | Dog | 2017-08-31 16:47:00 | Normal | Lockah | Intact Male |
-- | A382410 | Dog | 2017-10-19 14:59:00 | Normal | Dodo | Intact Female |
-- | A385350 | Dog | 2017-10-24 16:30:00 | Normal | Harley | Intact Female |
--
-- #### ANIMAL_OUTS (보호소 입양 정보)
-- | ANIMAL_ID | ANIMAL_TYPE | DATETIME | NAME | SEX_UPON_OUTCOME |
-- | --- | --- | --- | --- | --- |
-- | A355753 | Dog | 2017-08-11 16:05:00 | Elijah | Neutered Male |
-- | A373280 | Dog | 2017-09-02 17:15:00 | Lockah | Neutered Male |
-- | A382410 | Dog | 2017-10-22 15:31:00 | Dodo | Spayed Female |
-- | A385350 | Dog | 2017-10-26 17:21:00 | Harley | Intact Female |
--
-- #### 기대하는 출력 결과 (RESULT)
-- | ANIMAL_ID | ANIMAL_TYPE | NAME |
-- | --- | --- | --- |
-- | A373280 | Dog | Lockah |
-- | A382410 | Dog | Dodo |

-- %%
-- [문제 설명]
-- ANIMAL_INS 테이블과 ANIMAL_OUTS 테이블을 ANIMAL_ID로 조인합니다.
-- 입소 시점(SEX_UPON_INTAKE)에는 'Intact%'이고, 퇴소 시점(SEX_UPON_OUTCOME)에는 'Spayed%' 또는 'Neutered%'인 동물을 조회합니다.
-- 출력 컬럼: ANIMAL_ID, ANIMAL_TYPE, NAME
-- 결과는 ANIMAL_ID 기준 오름차순 정렬합니다.
SELECT
