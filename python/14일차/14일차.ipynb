# %% [markdown]
# # 14일차 Python 알고리즘 학습
#
# ## 문제 1: 완전탐색(Brute-force) - 피로도 (Level 2)
#
# - **문제 출처**: [프로그래머스 피로도](https://school.programmers.co.kr/learn/courses/30/lessons/87946)
#
# ---
#
# ### 문제 설명
#
# XX 마왕성에 탐험을 떠나려고 합니다. 이 게임에는 "피로도" 시스템이 있으며, 일정 피로도를 사용해서 던전을 탐험할 수 있습니다.
#
# 이때, 각 던전마다 탐험을 시작하기 위해 필요한 "최소 필요 피로도"와 던전을 탐험한 후 소모되는 "소모 피로도"가 있습니다.
#
# "최소 필요 피로도"는 해당 던전을 탐험하기 위해 가지고 있어야 하는 최소한의 피로도를 의미하며, "소모 피로도"는 던전을 탐험한 후 소모되는 피로도를 의미합니다.
#
# 유저의 현재 피로도 `k`와 각 던전별 ["최소 필요 피로도", "소모 피로도"] 가 담긴 2차원 배열 `dungeons`가 주어질 때, 유저가 탐험할 수 있는 최대 던전 수를 return 하도록 solution 함수를 완성해주세요.
#
# ---
#
# ### 입출력 예시 및 작동 흐름 설명
#
# | k | dungeons | return |
# | --- | --- | --- |
# | 80 | [[80, 20], [50, 40], [30, 10]] | 3 |
#
# #### 진행 과정 및 상세 작동 흐름
# 1. 현재 피로도는 80입니다.
# 2. [80, 20] -> [50, 40] -> [30, 10] 순서로 탐험 시:
#    - 첫 번째 던전 탐험 가능 (필요 80 <= 80), 탐험 후 남은 피로도: 80 - 20 = 60
#    - 두 번째 던전 탐험 가능 (필요 50 <= 60), 탐험 후 남은 피로도: 60 - 40 = 20
#    - 세 번째 던전 탐험 불가능 (필요 30 > 남은 20) -> 총 2개 탐험
# 3. 순서를 변경하여 [80, 20] -> [30, 10] -> [50, 40] 순서로 탐험 시:
#    - 첫 번째 던전 탐험 가능, 남은 피로도: 80 - 20 = 60
#    - 세 번째 던전 탐험 가능 (필요 30 <= 60), 남은 피로도: 60 - 10 = 50
#    - 두 번째 던전 탐험 가능 (필요 50 <= 50), 남은 피로도: 50 - 40 = 10 -> 총 3개 탐험
# 4. 따라서 탐험할 수 있는 최대 던전 수는 3입니다.

# %%
def solution(k, dungeons):
    answer = -1
    return answer

# %% [markdown]
# ---
#
# ## 문제 2: 깊이/너비 우선 탐색(DFS/BFS) - 여행경로 (Level 3)
#
# - **문제 출처**: [프로그래머스 여행경로](https://school.programmers.co.kr/learn/courses/30/lessons/43164)
#
# ---
#
# ### 문제 설명
#
# 주어진 항공권 `tickets`를 모두 이용하여 여행경로를 짜려고 합니다. 항상 "ICN" 공항에서 출발합니다.
#
# 항공권 정보가 담긴 2차원 배열 `tickets`가 주어질 때, 방문하는 공항 경로를 배열에 담아 return 하도록 solution 함수를 작성해주세요.
#
# - 모든 공항은 알파벳 대문자 3글자로 이루어집니다.
# - 주어진 공항 수는 3개 이상 10,000개 이하입니다.
# - `tickets`의 각 행 [a, b]는 a 공항에서 b 공항으로 가는 항공권이 있다는 의미입니다.
# - 주어진 항공권은 모두 사용해야 합니다.
# - 만일 가능한 경로가 2개 이상일 경우 알파벳 순서가 앞서는 경로를 return 합니다.
# - 모든 도시를 방문할 수 있는 경로만 주어집니다.
#
# ---
#
# ### 입출력 예시 및 작동 흐름 설명
#
# | tickets | return |
# | --- | --- |
# | [["ICN", "JFK"], ["HND", "IAD"], ["JFK", "HND"]] | ["ICN", "JFK", "HND", "IAD"] |
# | [["ICN", "SFO"], ["ICN", "ATL"], ["SFO", "ATL"], ["ATL", "ICN"], ["ATL", "SFO"]] | ["ICN", "ATL", "ICN", "SFO", "ATL", "SFO"] |
#
# #### 진행 과정 및 상세 작동 흐름 (두 번째 예시 기준)
# 1. ICN에서 출발하며, 갈 수 있는 목적지는 SFO와 ATL 2개가 있습니다.
# 2. 알파벳 순서가 앞서는 ATL을 먼저 선택합니다. (경로: ICN -> ATL)
# 3. ATL에서 이동 가능한 곳은 ICN과 SFO입니다. 알파벳 순으로 앞선 ICN을 선택합니다. (경로: ICN -> ATL -> ICN)
# 4. ICN에서 남아있는 티켓인 SFO로 이동합니다. (경로: ICN -> ATL -> ICN -> SFO)
# 5. SFO에서 남아있는 티켓인 ATL로 이동합니다. (경로: ICN -> ATL -> ICN -> SFO -> ATL)
# 6. ATL에서 마지막 티켓인 SFO로 이동합니다. (경로: ICN -> ATL -> ICN -> SFO -> ATL -> SFO)
# 7. 모든 티켓을 사용하였으므로 ["ICN", "ATL", "ICN", "SFO", "ATL", "SFO"]를 반환합니다.

# %%
def solution(tickets):
    answer = []
    return answer

# %% [markdown]
# ---
#
# ## 문제 3: 힙(Heap) - 이중우선순위큐 (Level 3)
#
# - **문제 출처**: [프로그래머스 이중우선순위큐](https://school.programmers.co.kr/learn/courses/30/lessons/42628)
#
# ---
#
# ### 문제 설명
#
# 이중 우선순위 큐는 다음 연산을 할 수 있는 자료구조를 말합니다.
#
# - `I 숫자`: 큐에 숫자를 삽입합니다.
# - `D 1`: 큐에서 최댓값을 삭제합니다.
# - `D -1`: 큐에서 최솟값을 삭제합니다.
#
# 이중 우선순위 큐가 할 연산 `operations`가 매개변수로 주어질 때, 모든 연산을 처리한 후 큐가 비어있으면 `[0,0]`, 비어있지 않으면 `[최댓값, 최솟값]`을 return 하도록 solution 함수를 구현해주세요.
#
# ---
#
# ### 입출력 예시 및 작동 흐름 설명
#
# | operations | return |
# | --- | --- |
# | ["I 16", "I -5643", "D -1", "D 1", "D 1", "I 123", "D -1"] | [0, 0] |
# | ["I 7", "I 5", "I -5", "D -1"] | [7, 5] |
#
# #### 진행 과정 및 상세 작동 흐름 (첫 번째 예시 기준)
# 1. "I 16", "I -5643" 수행: 큐에는 [16, -5643] 저장
# 2. "D -1" 수행: 최솟값(-5643) 삭제 후 큐에는 [16] 남음
# 3. "D 1" 수행: 최댓값(16) 삭제 후 큐는 비어있음 []
# 4. "D 1" 수행: 큐가 비어있으므로 무시
# 5. "I 123" 수행: 큐에 [123] 저장
# 6. "D -1" 수행: 최솟값(123) 삭제 후 큐는 비어있음 []
# 7. 모든 연산 후 큐가 비어있으므로 [0, 0] 반환

# %%
def solution(operations):
    answer = []
    return answer
