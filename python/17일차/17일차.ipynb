# %% [markdown]
# # 17일차 Python 알고리즘 학습
#
# ## 문제 1: 깊이/너비 우선 탐색(DFS/BFS) - 카카오프렌즈 컬러링북 (Level 2)
#
# - **문제 출처**: [프로그래머스 카카오프렌즈 컬러링북](https://school.programmers.co.kr/learn/courses/30/lessons/1829)
#
# ---
#
# ### 문제 설명
#
# 머쓱이는 게임 캐릭터의 스킨을 눌러 게임 스킨을 바꾸려 합니다.
# 편집자 어피치는 컬러링북의 난이도를 영역의 수로 정의하려고 합니다. 이때 영역이란 상하좌우로 연결된 같은 색상의 공간을 의미합니다.
#
# 그림이 담긴 2차원 배열 `picture`와 그림의 크기를 나타내는 `m`(그림의 세로 크기), `n`(그림의 가로 크기)이 매개변수로 주어질 때,
# 그림에 몇 개의 영역이 있으며 가장 큰 영역은 몇 칸으로 이루어져 있는지를 배열 `[영역의 개수, 가장 큰 영역의 넓이]` 형태로 return 하도록 solution 함수를 완성해주세요.
#
# - 1 <= `m`, `n` <= 100
# - `picture`의 원소는 0 이상 2^31 - 1 이하의 임의의 값입니다.
# - `picture`의 원소 중 값이 0인 경우는 색칠하지 않은 영역을 의미하며, 이 영역은 영역의 개수에 포함되지 않습니다.
#
# ---
#
# ### 입출력 예시
#
# | m | n | picture | answer |
# | --- | --- | --- | --- |
# | 6 | 4 | [[1, 1, 1, 0], [1, 2, 2, 0], [1, 0, 0, 1], [0, 0, 0, 1], [0, 0, 0, 3], [0, 0, 0, 3]] | [4, 5] |

# %%
# [문제 설명]
# 2차원 배열 picture에서 상하좌우로 연결된 같은 색상 칸은 하나의 영역입니다. (값 0은 색칠 안 한 영역, 제외)
# 그림 크기 m(세로), n(가로)와 picture가 주어질 때 영역의 개수와 가장 큰 영역의 넓이를 구합니다.
# [영역의 개수, 가장 큰 영역의 넓이] 형태의 배열을 return 하세요.


def solution(m, n, picture):
    answer = 0
    number_of_area = 0
    max_size_of_one_area = 0

    answer = [number_of_area, max_size_of_one_area]
    return answer

# %% [markdown]
# ---
#
# ## 문제 2: 깊이/너비 우선 탐색(DFS/BFS) - 리코쳇 로봇 (Level 2)
#
# - **문제 출처**: [프로그래머스 리코쳇 로봇](https://school.programmers.co.kr/learn/courses/30/lessons/169199)
#
# ---
#
# ### 문제 설명
#
# 리코쳇 로봇이라는 보드게임이 있습니다.
# 이 보드게임은 격자모양 게임판 위에서 말을 움직이는 게임으로, 말은 상하좌우로 움직일 수 있으며 한 번 움직이기 시작하면 장애물이나 벽에 부딪히기 전까지 계속해서 미끄러져 이동합니다.
#
# 게임판의 상태를 나타내는 문자열 배열 `board`가 주어졌을 때, 로봇을 시작 위치에서 목표 위치까지 최소 몇 번 이동해야 하는지 return 하도록 solution 함수를 완성해주세요.
# 만약 목표 위치에 도달할 수 없다면 -1을 return 해주세요.
#
# - `board`의 각 요소는 아래와 같은 문자로 이루어져 있습니다.
#   - `.` : 빈 공간을 의미합니다.
#   - `R` : 로봇의 처음 위치를 의미합니다.
#   - `D` : 장애물의 위치를 의미합니다.
#   - `G` : 목표 지점의 위치를 의미합니다.
# - 3 <= `board`의 길이 <= 100
# - 3 <= `board`의 각 요소의 길이 <= 100
# - `board`의 모든 요소의 길이는 동일합니다.
# - `R`과 `G`는 board에 각각 한 개씩 존재합니다.
#
# ---
#
# ### 입출력 예시
#
# | board | result |
# | --- | --- |
# | ["...D..R", ".D.G...", "....D.D", "D....D.", "..D...."] | 7 |
# | [".D.R", "....", ".G..", "...D"] | -1 |

# %%
# [문제 설명]
# 격자 board에서 로봇(R)은 상하좌우로 움직이며, 한 번 움직이면 장애물(D)이나 벽에 부딪히기 전까지 계속 미끄러집니다.
# 시작 위치(R)에서 목표 위치(G)까지 이동해야 하는 최소 이동 횟수를 구합니다.
# 목표에 도달할 수 없으면 -1을 return 하세요.


def solution(board):
    answer = 0

    return answer
